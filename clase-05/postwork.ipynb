# %%
"""
Crear la tabla para la base de datos y persistir los datos de las criptos

id => str
symbol => str
name => str
current_price_mxn => float
current_price_usd => float
updated_at => datetime (precision en segundos)

CREATE TABLE cryptos_prices (
    id VARCHAR(255),
    symbol VARCHAR(255),
    name VARCHAR(255),
    current_price_mxn FLOAT,
    current_price_usd FLOAT,
    updated_at TIMESTAMP
);


"""

# %%
## Esta es la preparacion de las tablas donde vamos a guardar los datos de las criptomonedas
import mysql.connector


# Crear una conexión a la base de datos.
mydb = mysql.connector.connect(
    host="ec2-35-87-249-145.us-west-2.compute.amazonaws.com",
    user="data",
    password="khQ9--mp6LWq97iA",
    database="tienda"

) # Pidele a tu Experto o Experta que te proporcione los datos de conexión.

# %%
import logging

logging.basicConfig(level=logging.DEBUG)

logging.info("Conectando a la base de datos")
logging.error("No se pudo conectar a la base de datos")
# Out:
# INFO:root:Conectando a la base de datos
# ERROR:root:No se pudo conectar a la base de datos

# %%
import requests
import time
import logging
import mysql.connector

logging.basicConfig(level=logging.DEBUG)

# Crear una conexión a la base de datos.
mydb = mysql.connector.connect(
    host="ec2-35-87-249-145.us-west-2.compute.amazonaws.com",
    user="data",
    password="khQ9--mp6LWq97iA",
    database="tienda"

) # Pidele a tu Experto o Experta que te proporcione los datos de conexión.

url = "https://api.coingecko.com/api/v3/coins/{}"

payload = {}
headers = {
  'api_key': 'CG-ivtfDGSQ8sALjJDvB55FGpnb',
  'Cookie': '__cf_bm=Bh0ds2z1WI0FpLxov9HwU6WDBp8jVQOl.1YoCnIuEVU-1721699002-1.0.1.1-tKPydXqcUKj9IY6j1ajC_DqQTf8atHeufbNcyp2jfM1NMC.mxqvV21Ki1oFnv43qaR31LUWm02seLrfc9UK3pQ'
}
bitcoin_id = 'bitcoin'
ethereum_id = 'ethereum'
mycursor = mydb.cursor()

while True:
  try:
    logging.info("Esperando 5 segundos...")
    time.sleep(5)
    logging.info("Haciendo petición a la API de Coingecko...")
    response = requests.request("GET", url.format(bitcoin_id), headers=headers, data=payload)
    bitcoin_data = response.json()
    id = bitcoin_data['id']
    symbol = bitcoin_data['symbol']
    name = bitcoin_data['name']
    current_price_mxn = bitcoin_data['market_data']['current_price']['mxn']
    current_price_usd = bitcoin_data['market_data']['current_price']['usd']
    mycursor.execute(f"""
      INSERT INTO cryptos_prices (id, symbol, name, current_price_mxn, current_price_usd, updated_at)
      VALUES ('{id}', '{symbol}', '{name}', {current_price_mxn}, {current_price_usd}, NOW())
    """)
    mydb.commit()
  except Exception as e:
    logging.error(f"Ocurrió un error: {e}")
# Out:
# DEBUG:mysql.connector:# _do_auth(): self._auth_plugin:
# DEBUG:mysql.connector:new_auth_plugin: caching_sha2_password
# INFO:root:Esperando 5 segundos...
# INFO:root:Haciendo petición a la API de Coingecko...
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.coingecko.com:443
# DEBUG:urllib3.connectionpool:https://api.coingecko.com:443 "GET /api/v3/coins/bitcoin HTTP/1.1" 200 None
# INFO:root:Esperando 5 segundos...
# INFO:root:Haciendo petición a la API de Coingecko...
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.coingecko.com:443
# DEBUG:urllib3.connectionpool:https://api.coingecko.com:443 "GET /api/v3/coins/bitcoin HTTP/1.1" 200 None
# INFO:root:Esperando 5 segundos...
# INFO:root:Haciendo petición a la API de Coingecko...
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.coingecko.com:443
# DEBUG:urllib3.connectionpool:https://api.coingecko.com:443 "GET /api/v3/coins/bitcoin HTTP/1.1" 200 None
# ...
