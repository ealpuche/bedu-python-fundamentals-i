# %%
import pandas as pd
import numpy as np

# Crear un DataFrame con datos y columnas más complejas
df = pd.DataFrame({
    'Nombre Completo': ['Juan Martínez', 'María Gómez', np.nan, 'Ana Torres', 'Sofía Núñez', np.nan, "Lena Marie", np.nan],
    'Edad al Cierre del Año': [28, 34, 19, np.nan, 45, np.nan, 1, np.nan],
    'Ciudad de Residencia Actual': ['Madrid', 'Barcelona', 'Sevilla', 'Valencia', 'Bilbao', np.nan, "Coahuila", np.nan],
    'Ingresos Anuales Estimados': [1200, 1500, 900, 1100, np.nan, np.nan, 1200, np.nan],
    'Área de Vivienda m²': [np.nan, 45, 70, 80, 60, np.nan, 120, np.nan],
    'Año de Construcción': [1990, 1985, np.nan, 2000, 2010, np.nan, np.nan, np.nan],
    'Reseña del Cliente': [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan]
})

# Convertir nombres de columnas a snake_case
df.columns = df.columns.str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# Mostrar el DataFrame inicial
df.head(10)
# Out:
#   nombre_completo  edad_al_cierre_del_año ciudad_de_residencia_actual  \
# 0   Juan Martínez                    28.0                      Madrid
# 1     María Gómez                    34.0                   Barcelona
# 2             NaN                    19.0                     Sevilla
# 3      Ana Torres                     NaN                    Valencia
# 4     Sofía Núñez                    45.0                      Bilbao
# 5             NaN                     NaN                         NaN
# 6      Lena Marie                     1.0                    Coahuila
# 7             NaN                     NaN                         NaN
#
#    ingresos_anuales_estimados  área_de_vivienda_m²  año_de_construcción  \
# 0                      1200.0                  NaN               1990.0
# 1                      1500.0                 45.0               1985.0
# 2                       900.0                 70.0                  NaN
# 3                      1100.0                 80.0               2000.0
# 4                         NaN                 60.0               2010.0
# 5                         NaN                  NaN                  NaN
# 6                      1200.0                120.0                  NaN
# 7                         NaN                  NaN                  NaN
#
#    reseña_del_cliente
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN

# %%
## Eliminar columnas 
# Eliminar columnas que no aportan información relevante
df.drop(columns=['área_de_vivienda_m²', 'año_de_construcción', 'reseña_del_cliente'], inplace=True)
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 3
#       1 ## Eliminar columnas
#       2 # Eliminar columnas que no aportan información relevante
# ----> 3 df.drop(columns=['área_de_vivienda_m²', 'año_de_construcción', 'reseña_del_cliente'], inplace=True)
#       4 df.head(10)
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/site-packages/pandas/core/frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/site-packages/pandas/core/generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/site-packages/pandas/core/generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/site-packages/pandas/core/indexes/base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['área_de_vivienda_m²', 'año_de_construcción', 'reseña_del_cliente'] not found in axis"

# %%
# Eliminar filas con valores faltantes
df.dropna(axis=0, how='any', inplace=True)
df.head(10)
# Out:
#   nombre_completo  edad_al_cierre_del_año ciudad_de_residencia_actual  \
# 0   Juan Martínez                    28.0                      Madrid
# 1     María Gómez                    34.0                   Barcelona
# 6      Lena Marie                     1.0                    Coahuila
#
#    ingresos_anuales_estimados
# 0                      1200.0
# 1                      1500.0
# 6                      1200.0

# %%
# Reindexar el DataFrame
new_df = df.reset_index(drop=False, inplace=False) # Mostrar cómo queda el índice sin eliminar el índice anterior
new_df
# Out:
#    index nombre_completo  edad_al_cierre_del_año ciudad_de_residencia_actual  \
# 0      0   Juan Martínez                    28.0                      Madrid
# 1      1     María Gómez                    34.0                   Barcelona
# 2      6      Lena Marie                     1.0                    Coahuila
#
#    ingresos_anuales_estimados
# 0                      1200.0
# 1                      1500.0
# 2                      1200.0

# %%
renombrado = {
    'nombre_completo': 'nombre',
    'edad_al_cierre_del_año': 'edad',
    'ciudad_de_residencia_actual': 'ciudad',
    'ingresos_anuales_estimados': 'ingresos'
}

df.rename(columns=renombrado, inplace=True)
df.head()
# Out:
#           nombre  edad     ciudad  ingresos  área_de_vivienda_m²  \
# 0  Juan Martínez  28.0     Madrid    1200.0                  NaN
# 1    María Gómez  34.0  Barcelona    1500.0                 45.0
# 2            NaN  19.0    Sevilla     900.0                 70.0
# 3     Ana Torres   NaN   Valencia    1100.0                 80.0
# 4    Sofía Núñez  45.0     Bilbao       NaN                 60.0
#
#    año_de_construcción  reseña_del_cliente
# 0               1990.0                 NaN
# 1               1985.0                 NaN
# 2                  NaN                 NaN
# 3               2000.0                 NaN
# 4               2010.0                 NaN
